# %%
import re
import numpy as np
import pandas as pd

# %%
# Load the listing file  (https://ta.wikisource.org/wiki/விக்கிமூலம்:முதற்_பக்கம்/புதிய_உரைகள்#பிற_நூல்கள்)
data_file = open('wikisource_listing.txt', 'r') 
lines = data_file.readlines()

# %%
# Read each item and parse the metadata
wikisource_books = []
for line in lines:
    metadata = {}    
    pattern = "xport\|(.*?)}}"
    title = re.search(pattern, line).group(1)
    metadata["title"] = title    
    metadata["source"] = "https://ta.wikisource.org/wiki/" + title
    
    metadata["creator"] = ""
    pattern2 = "\[\[ஆசிரியர்:(.*?)\|"
    creator = re.search(pattern2, line)
    if creator is not None:
        creator = creator.group(1)
        metadata["creator"] = creator
        
        
    metadata["subject"] = ""
    pattern3 = "பகுப்பு:(.*?)\|"
    subject = re.search(pattern3, line)
    if subject is not None:
        subject = subject.group(1)
        metadata["subject"] = subject
        
    metadata["date"] = ""
    pattern4 = "(\d{4})"
    date = re.search(pattern4, line)
    if date is not None:
        date = date.group(1)
        metadata["date"] = date  
    wikisource_books.append(metadata)

# %%
df = pd.DataFrame(wikisource_books) 
df.head(10)
# Out:
#                           title  \
# 0                   பழைய கணக்கு
# 1       பாப்பா முதல் பாட்டி வரை
# 2  எது வியாபாரம், எவர் வியாபாரி
# 3                     ஒரே உரிமை
# 4                 மணி பல்லவம் 1
# 5                 மணி பல்லவம் 2
# 6         புத்தர் பொன்மொழி நூறு
# 7    வேங்கடம் முதல் குமரி வரை 1
# 8    வேங்கடம் முதல் குமரி வரை 3
# 9    வேங்கடம் முதல் குமரி வரை 4
#
#                                               source  \
# 0         https://ta.wikisource.org/wiki/பழைய கணக்கு
# 1  https://ta.wikisource.org/wiki/பாப்பா முதல் பா...
# 2  https://ta.wikisource.org/wiki/எது வியாபாரம், ...
# 3           https://ta.wikisource.org/wiki/ஒரே உரிமை
# 4       https://ta.wikisource.org/wiki/மணி பல்லவம் 1
# 5       https://ta.wikisource.org/wiki/மணி பல்லவம் 2
# 6  https://ta.wikisource.org/wiki/புத்தர் பொன்மொழ...
# 7  https://ta.wikisource.org/wiki/வேங்கடம் முதல் ...
# 8  https://ta.wikisource.org/wiki/வேங்கடம் முதல் ...
# 9  https://ta.wikisource.org/wiki/வேங்கடம் முதல் ...
#
#                        creator subject  date
# 0                         சாவி          1984
# 1          புலவர் த. கோவேந்தன்
# 2        கி. ஆ. பெ. விசுவநாதம்          1994
# 3                      விந்தன்          1983
# 4             நா. பார்த்தசாரதி          2000
# 5             நா. பார்த்தசாரதி          2000
# 6       பேரா. சுந்தரசண்முகனார்          1987
# 7  தொ. மு. பாஸ்கரத் தொண்டைமான்          2000
# 8  தொ. மு. பாஸ்கரத் தொண்டைமான்          2001
# 9  தொ. மு. பாஸ்கரத் தொண்டைமான்          2001

# %%
df.to_csv("metadata.csv", index=False)
